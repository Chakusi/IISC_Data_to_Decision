# %%
import matplotlib.pyplot as plt
import pandas as pandas

df = pandas.read_csv('../data/City_wise_raw_data_1Day_2019_Delhi_1Day.csv')

print(df.head())
# Out:
#     Timestamp  PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  \
# 0  2019-01-01     288.412162    462.993529   86.539737    70.131842
# 1  2019-01-02     333.376486    517.637647   96.524211    76.732105
# 2  2019-01-03     348.411892    515.133824   66.843684    65.226053
# 3  2019-01-04     249.152895    399.860857   51.820513    58.564103
# 4  2019-01-05     255.339211    411.182286   61.673846    62.046410
#
#     NOx (ppb)  NH3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Ozone (µg/m³)  ...  \
# 0  117.235135    56.902500    17.915161    2.542222      28.371081  ...
# 1  131.174865    63.483929    18.744194    2.767222      29.736486  ...
# 2   96.229730    60.677500    14.927097    2.415000      23.857027  ...
# 3   77.806216    56.023103    13.340000    2.117297      18.100789  ...
# 4   85.935000    56.278667    15.476061    2.110811      25.542105  ...
#
#    MP-Xylene (µg/m³)    AT (°C)     RH (%)  WS (m/s)    WD (deg)  RF (mm)  \
# 0            7.92400  12.715833  65.516207  0.884643  194.328621   0.0000
# 1           10.53800  13.959583  69.112069  0.843704  163.207857   0.0000
# 2            8.04800  13.152500  72.292759  1.160370  212.633571   0.0000
# 3           10.57500  11.922400  76.450667  0.923214  192.008621   0.0000
# 4           15.86875  13.689231  64.851290  1.354828  154.112000   0.0005
#
#    TOT-RF (mm)  SR (W/mt2)   BP (mmHg)  VWS (m/s)
# 0   19849.1125   83.756071  966.867308   0.550000
# 1   41085.6375   74.066552  967.429615   0.403333
# 2   21474.3500   77.665517  968.945769   0.430000
# 3   16891.8875   61.049310  967.109630   0.296000
# 4   50316.8125   80.687586  966.198571   0.111667
#
# [5 rows x 25 columns]
